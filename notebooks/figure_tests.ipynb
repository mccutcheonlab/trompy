# %%
import trompy as tp
from pathlib import Path
import matplotlib.pyplot as plt

# %%
f, ax = plt.subplots()
ax.plot([1, 2, 3], [4, 5, 6])
tp.save_figure_atomic(f, "test_figure", folder=Path("test_figures"), save_pdf=True, save_png=True, dpi=300)
